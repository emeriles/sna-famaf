# %%
import json
import matplotlib.pyplot as plt
import pandas as pd


SCORES_FOLDER_1_ = "../src/modeling/_1_one_user_learn_neighbours/scores"

# %% [markdown]
# ### Scatter plot de pos cases en test

# %%
with open(SCORES_FOLDER_1_ + '/f1s_testv_None_svc.json', 'r') as f:
    f1s = json.load(f)
with open(SCORES_FOLDER_1_ + '/pos_cases_testv_None_svc.json', 'r') as f:
    pcs = json.load(f)

with open(SCORES_FOLDER_1_ + '/pos_cases_train_None_svc.json', 'r') as f:
    pcs_train = json.load(f)
    
rows = [{"f1": f1s[u_id], "n": pcs[u_id]} for u_id in f1s.keys()]
df1 = pd.DataFrame(rows)
df1.plot.scatter("n","f1")

# %%
vals = [pcs[u_id] + pcs_train[u_id] for u_id in f1s.keys()]
sum(vals) * 1.0 /  len(vals)
vals.sort(reverse=True)
v = vals[:35]
sum(v) *1.0 / len(v)
# Out:
# 1452.2857142857142

# %% [markdown]
# ### Scatter plot de pos cases en train

# %%
with open(SCORES_FOLDER_1_ + '/f1s_testv_None_svc.json', 'r') as f:
    f1s = json.load(f)
with open(SCORES_FOLDER_1_ + '/pos_cases_testv_None_svc.json', 'r') as f:
    pcs = json.load(f)

with open(SCORES_FOLDER_1_ + '/pos_cases_train_None_svc.json', 'r') as f:
    pcs_train = json.load(f)
    
rows = [{"f1": f1s[u_id], "n": pcs_train[u_id]} for u_id in f1s.keys()]
df2 = pd.DataFrame(rows)
df2.plot.scatter("n","f1")

# %%
# +200
print('Cantidad de casos positivos en test de usuarios ordenados de mayor a menor.')
df1.sort_values(by=['n'], ascending=False)
# Out:
# Cantidad de casos positivos en test de usuarios ordenados de mayor a menor.
#            f1    n
# 48   0.736196  260
# 133  0.748235  232
# 113  0.675000  230
# 160  0.757238  225
# 107  0.701571  213
# 127  0.661247  198
# 209  0.670391  197
# 42   0.922353  197
# 97   0.564286  196
# 153  0.872832  194
# 110  0.794118  193
# 53   0.621984  192
# 132  0.845304  189
# 50   0.707904  185
# 117  0.643478  181
# 207  0.497925  181
# 109  0.891089  180
# 18   0.462882  176
# 79   0.875622  176
# 75   0.708709  176
# 62   0.731392  175
# 189  0.907609  169
# 221  0.612100  166
# 101  0.839378  165
# 129  0.811940  163
# 190  0.690789  159
# 95   0.904762  158
# 145  0.908475  158
# 55   0.597484  155
# 21   0.599424  155
# ..        ...  ...
# 102  0.848485   57
# 142  0.525000   57
# 9    0.682353   56
# 125  0.422535   56
# 84   0.658824   55
# 33   0.709677   55
# 40   0.780142   55
# 120  0.743243   55
# 181  0.887097   55
# 45   0.620690   54
# 80   0.578947   54
# 57   0.794118   54
# 169  0.810811   53
# 147  0.691358   53
# 16   0.776699   53
# 56   0.981132   52
# 64   0.648649   52
# 212  0.843137   52
# 172  0.658228   52
# 111  0.775510   51
# 1    0.542857   51
# 162  0.661972   51
# 20   0.914894   51
# 25   0.842105   51
# 87   0.640000   51
# 176  0.891304   51
# 215  0.800000   50
# 124  0.853933   50
# 10   0.837607   49
# 106  0.918367   49
#
# [224 rows x 2 columns]

# %%
print('Cantidad de casos positivos en test de usuarios ordenados de mayor a menor.')
df2.sort_values(by=['n'], ascending=False)
# Out:
# Cantidad de casos positivos en test de usuarios ordenados de mayor a menor.
#            f1     n
# 48   0.736196  1818
# 133  0.748235  1625
# 113  0.675000  1611
# 160  0.757238  1574
# 107  0.701571  1490
# 127  0.661247  1387
# 42   0.922353  1380
# 209  0.670391  1378
# 97   0.564286  1373
# 153  0.872832  1361
# 110  0.794118  1352
# 53   0.621984  1347
# 132  0.845304  1325
# 50   0.707904  1294
# 207  0.497925  1266
# 117  0.643478  1265
# 109  0.891089  1262
# 75   0.708709  1234
# 79   0.875622  1233
# 18   0.462882  1230
# 62   0.731392  1223
# 189  0.907609  1181
# 221  0.612100  1162
# 101  0.839378  1155
# 129  0.811940  1138
# 190  0.690789  1114
# 95   0.904762  1105
# 145  0.908475  1104
# 21   0.599424  1086
# 55   0.597484  1083
# ..        ...   ...
# 77   0.871287   397
# 12   0.378378   396
# 9    0.682353   394
# 125  0.422535   393
# 120  0.743243   388
# 40   0.780142   387
# 84   0.658824   384
# 181  0.887097   383
# 33   0.709677   382
# 80   0.578947   379
# 57   0.794118   375
# 45   0.620690   375
# 169  0.810811   373
# 16   0.776699   372
# 147  0.691358   370
# 212  0.843137   366
# 56   0.981132   365
# 64   0.648649   363
# 172  0.658228   363
# 176  0.891304   358
# 20   0.914894   358
# 111  0.775510   358
# 162  0.661972   358
# 25   0.842105   357
# 1    0.542857   355
# 87   0.640000   355
# 215  0.800000   349
# 124  0.853933   349
# 106  0.918367   346
# 10   0.837607   346
#
# [224 rows x 2 columns]

# %%
def torreja(fname):
    with open(SCORES_FOLDER_1_ + fname, 'r') as f:
        d = json.load(f)
    values = [v for v in d.values()]
    values.sort(reverse=True)
    print('Hay {} usuarios procesados de 224'.format(len(values)))
    v = pd.Series(values)
    avg = sum(values) * 1.0 / len(values)
    print('Promedio de valores = {}'.format(avg))
    pos_cases = [pcs_train[u] for u in d.keys()]
#     print(pos_cases)
    print('Promedio de casos positivos en test= {}'.format(sum(pos_cases) * 1.0 / len(pos_cases) ))
    plt.plot(v)

# %% [markdown]
# ### Todos los usuarios de prueba sin filtrar por tiempo

# %%
torreja('/f1s_train_None_svc.json')
# Out:
# Hay 224 usuarios procesados de 224
# Promedio de valores = 0.5638223465899578
# Promedio de casos positivos en test= 682.1830357142857

# %%
torreja('/f1s_testv_None_svc.json')
# Out:
# Hay 224 usuarios procesados de 224
# Promedio de valores = 0.7215334429470082
# Promedio de casos positivos en test= 682.1830357142857

# %%
with open(SCORES_FOLDER_1_ + '/f1s_train_None_svc.json', 'r') as f:
    f1_train = json.load(f)
with open(SCORES_FOLDER_1_ + '/f1s_testv_None_svc.json', 'r') as f:
    f1_test = json.load(f)
uid = '146114434'
f1_train[uid], f1_test[uid]
# Out:
# (0.5115303983228512, 0.5428571428571428)

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd


SCORES_FOLDER_1_ = "../src/modeling/_1_one_user_learn_neighbours/scores"

# %% [markdown]
# ### Scatter plot de pos cases en train

# %%
with open(SCORES_FOLDER_1_ + '/f1s_train_None_svc.json', 'r') as f:
    f1s = json.load(f)
with open(SCORES_FOLDER_1_ + '/pos_cases_train_None_svc.json', 'r') as f:
    pcs = pcs_train = json.load(f)
    
rows = [{"f1": f1s[u_id], "n": pcs[u_id]} for u_id in f1s.keys()]
df1 = pd.DataFrame(rows)
df1.plot.scatter("n","f1")

# %% [markdown]
# ### Scatter plot de pos cases en test

# %%
with open(SCORES_FOLDER_1_ + '/f1s_testv_None_svc.json', 'r') as f:
    f1s = json.load(f)
with open(SCORES_FOLDER_1_ + '/pos_cases_testv_None_svc.json', 'r') as f:
    pcs = json.load(f)
    
rows = [{"f1": f1s[u_id], "n": pcs[u_id]} for u_id in f1s.keys()]
df2 = pd.DataFrame(rows)
df2.plot.scatter("n","f1")

# %%
# +200
print('Cantidad de casos positivos en train de usuarios ordenados de mayor a menor.')
df1.sort_values(by=['n'], ascending=False)
# Out:
# Cantidad de casos positivos en train de usuarios ordenados de mayor a menor.
#            f1     n
# 48   0.289031  1804
# 133  0.680226  1624
# 113  0.708891  1607
# 160  0.870234  1572
# 107  0.828111  1488
# 127  0.832422  1390
# 209  0.817546  1378
# 97   0.834316  1373
# 42   0.254697  1373
# 153  0.851730  1360
# 110  0.783082  1356
# 53   0.147007  1347
# 132  0.844156  1297
# 50   0.595122  1296
# 117  0.757724  1265
# 207  0.863271  1263
# 109  0.791333  1259
# 79   0.889371  1228
# 62   0.820091  1225
# 18   0.508847  1222
# 75   0.811493  1219
# 189  0.895364  1191
# 101  0.771377  1153
# 221  0.847764  1152
# 129  0.873987  1140
# 190  0.540748  1121
# 95   0.754430  1105
# 145  0.862330  1105
# 55   0.119795  1102
# 21   0.457932  1081
# ..        ...   ...
# 102  0.839181   397
# 9    0.790769   393
# 77   0.854227   393
# 125  0.812412   389
# 40   0.338330   388
# 120  0.510229   386
# 84   0.585635   384
# 181  0.677778   383
# 33   0.628952   377
# 57   0.429167   377
# 80   0.847858   377
# 45   0.288618   374
# 169  0.621622   374
# 147  0.840125   370
# 16   0.708955   369
# 56   0.000000   365
# 212  0.771930   362
# 176  0.861685   358
# 20   0.418511   358
# 111  0.760274   357
# 64   0.734499   357
# 172  0.568224   356
# 162  0.795455   356
# 25   0.515068   354
# 87   0.621094   353
# 1    0.839669   351
# 124  0.511628   350
# 10   0.765823   348
# 215  0.481481   348
# 106  0.926761   347
#
# [224 rows x 2 columns]

# %%
print('Cantidad de casos positivos en test de usuarios ordenados de mayor a menor.')
df2.sort_values(by=['n'], ascending=False)
# Out:
# Cantidad de casos positivos en test de usuarios ordenados de mayor a menor.
#            f1    n
# 48   0.322581  258
# 133  0.662577  232
# 113  0.642857  229
# 160  0.723022  225
# 107  0.595745  213
# 127  0.528678  198
# 209  0.521739  197
# 97   0.573529  196
# 42   0.277372  196
# 153  0.870056  194
# 110  0.524138  194
# 53   0.124481  192
# 50   0.571429  185
# 132  0.568750  185
# 117  0.468193  181
# 109  0.574939  180
# 207  0.496063  180
# 79   0.695035  175
# 62   0.699301  175
# 18   0.493506  174
# 75   0.592391  174
# 189  0.757679  170
# 101  0.625000  165
# 221  0.589641  165
# 129  0.721429  163
# 190  0.471761  160
# 145  0.547826  158
# 95   0.470255  158
# 55   0.080000  157
# 21   0.576369  154
# ..        ...  ...
# 12   0.473282   57
# 77   0.727273   56
# 9    0.682353   56
# 125  0.423529   56
# 120  0.538462   55
# 40   0.253968   55
# 181  0.612245   55
# 84   0.571429   55
# 33   0.660000   54
# 57   0.363636   54
# 80   0.607595   54
# 16   0.868852   53
# 147  0.641026   53
# 45   0.347826   53
# 169  0.564103   53
# 56   0.000000   52
# 212  0.688889   52
# 25   0.778626   51
# 20   0.927835   51
# 64   0.578313   51
# 172  0.582278   51
# 162  0.369231   51
# 111  0.631579   51
# 176  0.891304   51
# 1    0.529412   50
# 215  0.317460   50
# 87   0.666667   50
# 10   0.652632   50
# 124  0.434783   50
# 106  0.884211   49
#
# [224 rows x 2 columns]

# %%
def torreja(fname):
    with open(SCORES_FOLDER_1_ + fname, 'r') as f:
        d = json.load(f)
    values = [v for v in d.values()]
    values.sort(reverse=True)
    print('Hay {} usuarios procesados de 224'.format(len(values)))
    v = pd.Series(values)
    avg = sum(values) * 1.0 / len(values)
    print('Promedio de valores = {}'.format(avg))
    pos_cases = [pcs_train[u] for u in d.keys()]
#     print(pos_cases)
    print('Promedio de casos positivos en test= {}'.format(sum(pos_cases) * 1.0 / len(pos_cases) ))
    plt.plot(v)

# %% [markdown]
# ### Todos los usuarios de prueba sin filtrar por tiempo

# %%
torreja('/f1s_train_None_svc.json')
# Out:
# Hay 224 usuarios procesados de 224
# Promedio de valores = 0.6957176815199498
# Promedio de casos positivos en test= 681.8214285714286

# %%
torreja('/f1s_testv_None_svc.json')
# Out:
# Hay 224 usuarios procesados de 224
# Promedio de valores = 0.567995583631382
# Promedio de casos positivos en test= 681.8214285714286

# %%
with open(SCORES_FOLDER_1_ + '/f1s_train_None_svc.json', 'r') as f:
    f1_train = json.load(f)
with open(SCORES_FOLDER_1_ + '/f1s_testv_None_svc.json', 'r') as f:
    f1_test = json.load(f)
uid = '53062387'
f1_train[uid], f1_test[uid]
# Out:
# (0.7907692307692308, 0.6823529411764707)
